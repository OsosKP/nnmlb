# %%
import pandas as pd

# %%
df_all = pd.read_csv('../core/data/FanGraphsLeagueAverages.csv')

# %%
df_al = pd.read_csv('../core/data/al_pa.csv')
df_nl = pd.read_csv('../core/data/nl_pa.csv')

# %%
df_al = df_al['PA']
df_nl = df_nl['PA']

# %%
df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101 entries, 0 to 100
# Data columns (total 19 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Season  101 non-null    int64
#  1   PA      101 non-null    int64
#  2   BB%     101 non-null    object
#  3   K%      101 non-null    object
#  4   BB/K    101 non-null    float64
#  5   AVG     101 non-null    float64
#  6   OBP     101 non-null    float64
#  7   SLG     101 non-null    float64
#  8   OPS     101 non-null    float64
#  9   ISO     101 non-null    float64
#  10  Spd     101 non-null    float64
#  11  BABIP   101 non-null    float64
#  12  UBR     18 non-null     float64
#  13  wGDP    18 non-null     float64
#  14  wSB     101 non-null    float64
#  15  wRC     101 non-null    int64
#  16  wRAA    101 non-null    float64
#  17  wOBA    101 non-null    float64
#  18  wRC+    101 non-null    int64
# dtypes: float64(13), int64(4), object(2)
# memory usage: 15.1+ KB

# %%
df_all.insert(loc=2, column='PA_AL', value=df_al)
df_all.insert(loc=2, column='PA_NL', value=df_nl)

# %%
df_all
# Out:
#      Season      PA  PA_NL  PA_AL    BB%      K%  BB/K    AVG    OBP    SLG  \
# 0      1919   83902  41362  42540  7.1 %   8.2 %  0.87  0.263  0.322  0.348
# 1      1920   94601  46893  47708  7.2 %   7.7 %  0.94  0.276  0.335  0.372
# 2      1921   95556  46956  48600  7.2 %   7.3 %  0.98  0.291  0.348  0.403
# 3      1922   96155  48149  48006  7.5 %   7.2 %  1.04  0.288  0.348  0.401
# 4      1923   96130  48087  48043  7.9 %   7.3 %  1.08  0.284  0.347  0.391
# ..      ...     ...    ...    ...    ...     ...   ...    ...    ...    ...
# 96     2015  183627  91790  91837  7.7 %  20.4 %  0.38  0.254  0.317  0.405
# 97     2016  184578  92539  92039  8.2 %  21.1 %  0.39  0.255  0.322  0.417
# 98     2017  185295  92673  92622  8.5 %  21.6 %  0.39  0.255  0.324  0.426
# 99     2018  185139  92885  92254  8.5 %  22.3 %  0.38  0.248  0.318  0.409
# 100    2019  186516  93237  93279  8.5 %  23.0 %  0.37  0.252  0.323  0.435
#
# ...

# %%
df_all.to_csv('../core/data/FanGraphsLeagueAverages.csv', index=False, float_format='%g')
