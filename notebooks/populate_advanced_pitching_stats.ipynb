# %%
import pandas as pd

# %%
df_names = pd.read_csv('../core/data/Names.csv')
df_stats = pd.read_csv('../core/data/FanGraphsPitching.csv')

# %%
df_stats
# Out:
#                   Name    Team    W    L  SV    G   GS      IP    K/9  BB/9  \
# 0        Roger Clemens   - - -  354  184   0  709  707  4916.2   8.55  2.89
# 1          Greg Maddux   - - -  355  227   0  744  740  5008.1   6.06  1.80
# 2        Randy Johnson   - - -  303  166   2  618  603  4135.1  10.61  3.26
# 3           Nolan Ryan   - - -  324  292   3  807  773  5386.0   9.55  4.67
# 4        Bert Blyleven   - - -  287  250   0  692  685  4970.0   6.70  2.39
# ...                ...     ...  ...  ...  ..  ...  ...     ...    ...   ...
# 8020  Darrel Akerfelds   - - -    9   10   3  125   13   233.2   4.97  4.89
# 8021        Dave Jolly  Braves   16   14  19  159    1   291.1   4.79  6.12
# 8022       Bill Laxton   - - -    3   10   5  121    4   243.1   6.99  5.84
# 8023       Pat Mahomes   - - -   42   39   5  308   63   709.0   5.74  4.98
# 8024        Alan Mills   - - -   39   32  15  474    5   636.0   6.45  5.59
#
# ...
